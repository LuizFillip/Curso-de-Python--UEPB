# %% [markdown]
# # Matplotlib
#
# Matplotlib é uma biblioteca abrangente para criar estática, animada, e visualizações interativas em Python. Matplotlib torna as coisas fáceis coisas fáceis e difíceis possíveis.
#
# ![image-2.png](attachment:image-2.png)

# %%
import matplotlib.pyplot as plt 
import numpy as np 

x = np.arange(0, 50, 1)

# loop com varios periodos 

for period in np.arange(1, 7, 2):
    
    y = 4 * np.sin(np.pi * x / period)

    plt.plot(x, y, label = f'T = {period} s')
    plt.xlabel('time (s)')
    plt.ylabel('amplitude')
    plt.title('Função seno')

    plt.legend()

# %%
# sub-gráficos 

fig, ax = plt.subplots(
    #ncols = 2, 
    nrows = 2
)

#ax[0, 0].plot(x, y)
ax[1].plot(x, y)
ax[0].plot(x, y **2)

# %%
# Gráficos de dispersão

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)

# %%
x
z = np.meshgrid(x, y)[0]

plt.imshow(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x
#       2 z = np.meshgrid(x, y)[0]
#       4 plt.imshow(z)
#
# NameError: name 'x' is not defined

# %% [markdown]
# # Mapas - Cartopy

# %%
import matplotlib.pyplot as plt
import cartopy.feature as cf
import cartopy.crs as ccrs
import numpy as np 

fig, ax = plt.subplots(
    subplot_kw = 
        {'projection': ccrs.PlateCarree()}
)

ax.add_feature(cf.COASTLINE)

ylimits = [-90, 90]
xlimits = [-90, -30]
ax.set_extent(
    [-90, -30, -90, 90], 
        crs = ccrs.PlateCarree())

ax.set_yticks(
    np.arange(ylimits[0], ylimits[-1], 15)
)
ax.set_xticks(
    np.arange(xlimits[0], xlimits[-1], 30)
)

plt.show()

# %%
# !git add .
# !git commit -m "Aula de Matplotlib"
# !git push
# Out:
# warning: LF will be replaced by CRLF in Matplotlib.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in Pandas.ipynb.
# The file will have its original line endings in your working directory
# [main 755d235] Aula de Matplotlib
#  2 files changed, 219 insertions(+), 52 deletions(-)
# To https://github.com/LuizFillip/Curso-de-Python--UEPB.git
#    33a5572..755d235  main -> main
